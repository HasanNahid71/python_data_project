# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\utils\_http.py:420, in hf_raise_for_status(response, endpoint_name)
#     418         elif error_code == "EntryNotFound":
#     419             message = f"{response.status_code} Client Error." + "\n\n" + f"Entry Not Found for url: {response.url}."
# --> 420             raise _format(EntryNotFoundError, message, response) from e
#     421
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\requests\models.py:1167, in Response.raise_for_status(self)
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/datasets/lukebarousse/data_jobs/resolve/ed776e5a0a8c40ea9d5efbd800772ae52e140f3e/data_jobs.py
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# File c:\Users\Nahid\anaconda3\Lib\site-packages\datasets\load.py:1168, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1167 try:
# -> 1168     api.hf_hub_download(
#    1169         repo_id=path,
#    1170         filename=filename,
#    1171         repo_type="dataset",
#    1172         revision=commit_hash,
#    1173         proxies=download_config.proxies,
#    1174     )
#    1175     raise RuntimeError(f"Dataset scripts are no longer supported, but found {filename}")
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\hf_api.py:5248, in HfApi.hf_hub_download(self, repo_id, filename, subfolder, repo_type, revision, cache_dir, local_dir, force_download, proxies, etag_timeout, token, local_files_only, resume_download, force_filename, local_dir_use_symlinks)
#    5246             token = self.token
#    5247
# -> 5248         return hf_hub_download(
#    5249             repo_id=repo_id,
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\file_download.py:862, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     860         )
#     861     else:
# --> 862         return _hf_hub_download_to_cache_dir(
#     863             # Destination
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\file_download.py:925, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#     923     # Try to get metadata (etag, commit_hash, url, size) from the server.
#     924     # If we can't, a HEAD request error is returned.
# --> 925     (url_to_download, etag, commit_hash, expected_size, head_call_error) = _get_metadata_or_catch_error(
#     926         repo_id=repo_id,
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\file_download.py:1441, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1439         except (RevisionNotFoundError, EntryNotFoundError):
#    1440             # The repo was found but the revision or entry doesn't exist on the Hub (never existed or got deleted)
# -> 1441             raise
#    1442         except requests.HTTPError as error:
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\file_download.py:1296, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1294
#    1295     # Retrieve metadata
# -> 1296     r = _request_wrapper(
#    1297         method="HEAD",
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\file_download.py:280, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     278     # Recursively follow relative redirects
#     279     if follow_relative_redirects:
# --> 280         response = _request_wrapper(
#     281             method=method,
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\file_download.py:304, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     302     # Perform request and return if status_code is not in the retry list.
#     303     response = get_session().request(method=method, url=url, **params)
# --> 304     hf_raise_for_status(response)
#     305     return response
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\utils\_http.py:420, in hf_raise_for_status(response, endpoint_name)
#     418         elif error_code == "EntryNotFound":
#     419             message = f"{response.status_code} Client Error." + "\n\n" + f"Entry Not Found for url: {response.url}."
# --> 420             raise _format(EntryNotFoundError, message, response) from e
#     421
#
# EntryNotFoundError: 404 Client Error. (Request ID: Root=1-6a89a745-4e3fc8c37a18cb233dd97262;4997d360-f633-4fe8-bdb4-d69498704dcf)
#
# Entry Not Found for url: https://huggingface.co/datasets/lukebarousse/data_jobs/resolve/ed776e5a0a8c40ea9d5efbd800772ae52e140f3e/data_jobs.py.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 7
#       3 from datasets import load_dataset
#       4 import matplotlib.pyplot as plt
#       5
#       6 # Loading Data
# ----> 7 dataset = load_dataset('lukebarousse/data_jobs')
#       8 df = dataset['train'].to_pandas()
#       9
#      10 # Data Cleanup
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\datasets\load.py:1696, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1691 verification_mode = VerificationMode(
#    1692     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1693 )
#    1695 # Create a dataset builder
# -> 1696 builder_instance = load_dataset_builder(
#    1697     path=path,
#    1698     name=name,
#    1699     data_dir=data_dir,
#    1700     data_files=data_files,
#    1701     cache_dir=cache_dir,
#    1702     features=features,
#    1703     download_config=download_config,
#    1704     download_mode=download_mode,
#    1705     revision=revision,
#    1706     token=token,
#    1707     storage_options=storage_options,
#    1708     **config_kwargs,
#    1709 )
#    1711 # Return iterable dataset in case of streaming
#    1712 if streaming:
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\datasets\load.py:1323, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1321 if features is not None:
#    1322     features = _fix_for_backward_compatible_features(features)
# -> 1323 dataset_module = dataset_module_factory(
#    1324     path,
#    1325     revision=revision,
#    1326     download_config=download_config,
#    1327     download_mode=download_mode,
#    1328     data_dir=data_dir,
#    1329     data_files=data_files,
#    1330     cache_dir=cache_dir,
#    1331 )
#    1332 # Get dataset builder class
#    1333 builder_kwargs = dataset_module.builder_kwargs
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\datasets\load.py:1190, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1180     else:
#    1181         use_exported_dataset_infos = True
#    1182     return HubDatasetModuleFactory(
#    1183         path,
#    1184         commit_hash=commit_hash,
#    1185         data_dir=data_dir,
#    1186         data_files=data_files,
#    1187         download_config=download_config,
#    1188         download_mode=download_mode,
#    1189         use_exported_dataset_infos=use_exported_dataset_infos,
# -> 1190     ).get_module()
#    1191 except GatedRepoError as e:
#    1192     message = f"Dataset '{path}' is a gated dataset on the Hub."
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\datasets\load.py:625, in HubDatasetModuleFactory.get_module(self)
#     623 if config.USE_PARQUET_EXPORT and self.use_exported_dataset_infos:
#     624     try:
# --> 625         exported_dataset_infos = _dataset_viewer.get_exported_dataset_infos(
#     626             dataset=self.name, commit_hash=self.commit_hash, token=self.download_config.token
#     627         )
#     628         exported_dataset_infos = DatasetInfosDict(
#     629             {
#     630                 config_name: DatasetInfo.from_dict(exported_dataset_infos[config_name])
#     631                 for config_name in exported_dataset_infos
#     632             }
#     633         )
#     634     except _dataset_viewer.DatasetViewerError:
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\datasets\utils\_dataset_viewer.py:71, in get_exported_dataset_infos(dataset, commit_hash, token)
#      69 dataset_viewer_info_url = config.HF_ENDPOINT.replace("://", "://datasets-server.") + "/info?dataset="
#      70 try:
# ---> 71     info_response = get_session().get(
#      72         url=dataset_viewer_info_url + dataset,
#      73         headers=get_authentication_headers_for_url(config.HF_ENDPOINT + f"datasets/{dataset}", token=token),
#      74         timeout=100.0,
#      75     )
#      76     info_response.raise_for_status()
#      77     if "X-Revision" in info_response.headers:
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\requests\sessions.py:671, in Session.get(self, url, params, **kwargs)
#     661 r"""Sends a GET request. Returns :class:`Response` object.
#     662
#     663 :param url: URL for the new :class:`Request` object.
#    (...)    667 :rtype: requests.Response
#     668 """
#     670 kwargs.setdefault("allow_redirects", True)
# --> 671 return self.request("GET", url, params=params, **kwargs)
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\requests\sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\huggingface_hub-0.29.2-py3.8.egg\huggingface_hub\utils\_http.py:97, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      93         if constants.HF_DEBUG:
#      94             logger.debug(f"Send: {_curlify(request)}")
#      95         try:
#      96             return super().send(request, *args, **kwargs)
# ---> 97         except requests.RequestException as e:
#      98             request_id = request.headers.get(X_AMZN_TRACE_ID)
#      99             if request_id is not None:
#     100                 # Taken from https://stackoverflow.com/a/58270258
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\requests\adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     693     resolved_timeout = TimeoutSauce(connect=timeout, read=timeout)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#     711     raise ConnectionError(err, request=request)
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785 response_conn = conn if not release_conn else None
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#     804 clean_exit = True
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Nahid\anaconda3\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Nahid\anaconda3\Lib\http\client.py:1459, in HTTPConnection.getresponse(self)
#    1457 try:
#    1458     try:
# -> 1459         response.begin()
#    1460     except ConnectionError:
#    1461         self.close()
#
# File c:\Users\Nahid\anaconda3\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File c:\Users\Nahid\anaconda3\Lib\http\client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File c:\Users\Nahid\anaconda3\Lib\socket.py:729, in SocketIO.readinto(self, b)
#     727     raise OSError("cannot read from timed out object")
#     728 try:
# --> 729     return self._sock.recv_into(b)
#     730 except timeout:
#     731     self._timeout_occurred = True
#
# File c:\Users\Nahid\anaconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Nahid\anaconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_US = df[df['job_country'] == 'United States'].copy()

# %%
df_US
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# 785673                    Asset Management Data Scientist      New York, NY
# 785685                                       Data Analyst  Indianapolis, IN
# 785692               Data Scientist- Hybrid Work Location        Dayton, OH
# 785703            Data Analyst - CRYPTOGRAPHY - Full-time          Anywhere
# 785705          Expert Business Data Analyst - Now Hiring       Oakland, CA
#
#                   job_via         job_schedule_type  job_work_from_home  \
# 0         via Work Nearby                 Full-time               False
# 3       via Diversity.com                 Full-time               False
# 5        via ZipRecruiter  Contractor and Temp work                True
# 6            via LinkedIn                 Full-time               False
# 9        via ZipRecruiter                 Full-time                True
# ...                   ...                       ...                 ...
# 785673    via Trabajo.org                 Full-time               False
# 785685    via Trabajo.org                 Full-time               False
# 785692    via Ai-Jobs.net                 Full-time               False
# 785703       via Snagajob                 Full-time                True
# 785705       via Snagajob                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 0            Texas, United States 2023-06-16 13:44:15                  False
# 3            Texas, United States 2023-07-04 13:01:41                   True
# 5                         Georgia 2023-11-07 14:01:59                  False
# 6          Florida, United States 2023-03-27 13:18:18                  False
# 9         New York, United States 2023-04-23 13:02:57                  False
# ...                           ...                 ...                    ...
# 785673    New York, United States 2023-10-16 06:01:53                   True
# 785685    Illinois, United States 2023-07-16 06:01:27                   True
# 785692    Illinois, United States 2023-04-21 06:02:31                  False
# 785703       Texas, United States 2023-01-28 06:02:55                   True
# 785705  California, United States 2023-01-09 06:00:25                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                      False  United States         NaN              NaN
# 3                      False  United States         NaN              NaN
# 5                      False  United States         NaN              NaN
# 6                      False  United States         NaN              NaN
# 9                      False  United States         NaN              NaN
# ...                      ...            ...         ...              ...
# 785673                 False  United States         NaN              NaN
# 785685                 False  United States         NaN              NaN
# 785692                  True  United States        year         157500.0
# 785703                 False  United States         NaN              NaN
# 785705                 False  United States         NaN              NaN
#
#         salary_hour_avg                   company_name  \
# 0                   NaN           Boehringer Ingelheim
# 3                   NaN   Southwest Research Institute
# 5                   NaN                smart folks inc
# 6                   NaN  Miracle Software Systems, Inc
# 9                   NaN     Radwell International, LLC
# ...                 ...                            ...
# 785673              NaN           JPMorgan Chase & Co.
# 785685              NaN         Aara Technologies, Inc
# 785692              NaN                         Tenet3
# 785703              NaN    Axelon Services Corporation
# 785705              NaN               PG&E Corporation
#
#                                                job_skills  \
# 0                                                     NaN
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                ['python', 'sql', 'gcp']
# 6       ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                   ...
# 785673                                                NaN
# 785685                                   ['sql', 'excel']
# 785692                          ['python', 'matlab', 'r']
# 785703                                                NaN
# 785705                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills
# 0                                                     NaN
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5       {'cloud': ['gcp'], 'programming': ['python', '...
# 6       {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9       {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                   ...
# 785673                                                NaN
# 785685  {'analyst_tools': ['excel'], 'programming': ['...
# 785692         {'programming': ['python', 'matlab', 'r']}
# 785703                                                NaN
# 785705  {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %%
df_US['job_posted_monthly'] = df_US['job_posted_date'].dt.strftime('%B')
df_US
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# 785673                    Asset Management Data Scientist      New York, NY
# 785685                                       Data Analyst  Indianapolis, IN
# 785692               Data Scientist- Hybrid Work Location        Dayton, OH
# 785703            Data Analyst - CRYPTOGRAPHY - Full-time          Anywhere
# 785705          Expert Business Data Analyst - Now Hiring       Oakland, CA
#
#                   job_via         job_schedule_type  job_work_from_home  \
# 0         via Work Nearby                 Full-time               False
# 3       via Diversity.com                 Full-time               False
# 5        via ZipRecruiter  Contractor and Temp work                True
# 6            via LinkedIn                 Full-time               False
# 9        via ZipRecruiter                 Full-time                True
# ...                   ...                       ...                 ...
# 785673    via Trabajo.org                 Full-time               False
# 785685    via Trabajo.org                 Full-time               False
# 785692    via Ai-Jobs.net                 Full-time               False
# 785703       via Snagajob                 Full-time                True
# 785705       via Snagajob                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 0            Texas, United States 2023-06-16 13:44:15                  False
# 3            Texas, United States 2023-07-04 13:01:41                   True
# 5                         Georgia 2023-11-07 14:01:59                  False
# 6          Florida, United States 2023-03-27 13:18:18                  False
# 9         New York, United States 2023-04-23 13:02:57                  False
# ...                           ...                 ...                    ...
# 785673    New York, United States 2023-10-16 06:01:53                   True
# 785685    Illinois, United States 2023-07-16 06:01:27                   True
# 785692    Illinois, United States 2023-04-21 06:02:31                  False
# 785703       Texas, United States 2023-01-28 06:02:55                   True
# 785705  California, United States 2023-01-09 06:00:25                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                      False  United States         NaN              NaN
# 3                      False  United States         NaN              NaN
# 5                      False  United States         NaN              NaN
# 6                      False  United States         NaN              NaN
# 9                      False  United States         NaN              NaN
# ...                      ...            ...         ...              ...
# 785673                 False  United States         NaN              NaN
# 785685                 False  United States         NaN              NaN
# 785692                  True  United States        year         157500.0
# 785703                 False  United States         NaN              NaN
# 785705                 False  United States         NaN              NaN
#
#         salary_hour_avg                   company_name  \
# 0                   NaN           Boehringer Ingelheim
# 3                   NaN   Southwest Research Institute
# 5                   NaN                smart folks inc
# 6                   NaN  Miracle Software Systems, Inc
# 9                   NaN     Radwell International, LLC
# ...                 ...                            ...
# 785673              NaN           JPMorgan Chase & Co.
# 785685              NaN         Aara Technologies, Inc
# 785692              NaN                         Tenet3
# 785703              NaN    Axelon Services Corporation
# 785705              NaN               PG&E Corporation
#
#                                                job_skills  \
# 0                                                     NaN
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                ['python', 'sql', 'gcp']
# 6       ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                   ...
# 785673                                                NaN
# 785685                                   ['sql', 'excel']
# 785692                          ['python', 'matlab', 'r']
# 785703                                                NaN
# 785705                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills job_posted_monthly
# 0                                                     NaN               June
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...               July
# 5       {'cloud': ['gcp'], 'programming': ['python', '...           November
# 6       {'cloud': ['gcp', 'bigquery'], 'databases': ['...              March
# 9       {'analyst_tools': ['excel'], 'cloud': ['azure'...              April
# ...                                                   ...                ...
# 785673                                                NaN            October
# 785685  {'analyst_tools': ['excel'], 'programming': ['...               July
# 785692         {'programming': ['python', 'matlab', 'r']}              April
# 785703                                                NaN            January
# 785705  {'analyst_tools': ['tableau'], 'programming': ...            January
#
# [206292 rows x 18 columns]

# %%
df_US_pivot = df_US.pivot_table(index='job_posted_monthly', columns='job_title_short', aggfunc='size')

# %%
df_US_pivot = df_US.pivot_table(index='job_posted_monthly', columns='job_title_short', aggfunc='size')
df_US_pivot.reset_index(inplace=True)
df_US_pivot['month_no'] = pd.to_datetime(df_US_pivot['job_posted_monthly'], format='%B').dt.month
df_US_pivot.sort_values('month_no', inplace=True)
df_US_pivot.set_index('job_posted_monthly', inplace=True)
df_US_pivot.drop(columns='month_no', inplace=True)

# %%
df_US_pivot
# Out:
# job_title_short     Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_monthly
# January                          527              36          8494
# February                         447              24          6124
# March                            438              19          6218
# April                            565              40          6049
# May                              279              20          4993
# June                             446              32          5683
# July                             581              39          5201
# August                           903              39          6634
# September                        897              50          4639
# October                          932              48          5271
# November                         719              36          4531
# December                         648              40          3979
#
# job_title_short     Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_monthly
# January                      2655            6915                         60
# February                     3060            4956                         56
# March                        3183            4779                         59
# April                        2801            4867                         51
# May                          2976            4377                         49
# June                         2893            4645                         48
# July                         2570            4876                         65
# August                       3269            6318                         68
# September                    3224            4568                        113
# October                      3015            4882                        101
# November                     2793            4175                        132
# December                     2641            3472                        119
#
# job_title_short     Senior Data Analyst  Senior Data Engineer  \
# job_posted_monthly
# January                            1544                   773
# February                           1258                   878
# March                              1114                   829
# April                              1025                   781
# May                                 839                   746
# June                               1009                   812
# July                                883                   747
# August                             1186                   903
# September                           805                   775
# October                             871                   672
# November                            656                   684
# December                            601                   689
#
# job_title_short     Senior Data Scientist  Software Engineer
# job_posted_monthly
# January                              1552                114
# February                             1127                 90
# March                                1150                115
# April                                 991                112
# May                                   914                 90
# June                                 1033                 93
# July                                 1095                153
# August                               1515                194
# September                            1014                228
# October                               987                219
# November                              816                194
# December                              752                212

# %%
df_US_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_monthly'>

# %%
top_3 = df_US['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()

# %%
df_US_pivot[top_3].plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_monthly'>

# %%
df_US_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()
